# %% [markdown]
# <img src="https://raw.githubusercontent.com/autonomousvision/navsim/main/assets/navsim_transparent.png" alt="drawing" width="800"/>

# %% [markdown]
# # NAVSIM Visualization Tutorial
#
# This notebook will introduce some basic plots to visualize the driving scenes in NAVSIM. All plots are created with `matplotlib` and are easy to customize for your application.
#
# ## Table of Contents
# 1. [Config](#config)
# 2. [Birds-Eye-View](#bev)
# 3. [Cameras](#camera)
# 4. [Creating custom plots](#custom)
# 5. [Creating GIFs](#gifs)

# %% [markdown]
# ## Config <a name="config"></a>
#
# NAVSIM offers two types of plots:
# - Birds-Eye-View (BEV) plots or
# - Camera plots.
#
# The LiDAR sensor can be visualized either in BEV or in camera images. All plots have a global configuration in [`navsim/visualization/config.py`](https://github.com/autonomousvision/navsim/blob/main/navsim/navsim/visualization/config.py). In this Python file, you can configure all colors or dimensions. The LiDAR point cloud can be colored in any colormap, showing the distance to the ego vehicle or the height of each point. In this tutorial, we first instantiate a `SceneFilter` and `SceneLoader` from the mini split.

# %%
import os
from pathlib import Path

import hydra
from hydra.utils import instantiate
import numpy as np
import matplotlib.pyplot as plt

from navsim.common.dataloader import SceneLoader
from navsim.common.dataclasses import SceneFilter, SensorConfig

SPLIT = "test"  # ["mini", "test", "trainval"]
FILTER = "navtest" #不要用test,也不要用all
from hydra.core.global_hydra import GlobalHydra


GlobalHydra.instance().clear()
hydra.initialize(config_path="../navsim/planning/script/config/common/train_test_split/scene_filter")

SPLIT = "test"
FILTER = "navtest"

GlobalHydra.instance().clear()
hydra.initialize(config_path="../navsim/planning/script/config/pdm_scoring")

cfg = hydra.compose(
    config_name="default_run_pdm_score",
    overrides=[f"train_test_split={FILTER}"],  # navtest
)

scene_filter: SceneFilter = instantiate(cfg.train_test_split.scene_filter)


# cfg = hydra.compose(config_name=FILTER)
# scene_filter: SceneFilter = instantiate(cfg)
# scene_filter: SceneFilter = instantiate(cfg.train_test_split.scene_filter) 
# openscene_data_root = Path(os.getenv("OPENSCENE_DATA_ROOT"))
openscene_data_root=Path("/workspace/wangch8@xiaopeng.com/dataset/navsim")

scene_loader = SceneLoader(
    openscene_data_root / f"navsim_logs/{SPLIT}",
    openscene_data_root / f"sensor_blobs/{SPLIT}",
    scene_filter,#这个不对，需要读取别的
    sensor_config=SensorConfig(cam_f0=[3], cam_l0=[3], cam_l1=[3], cam_l2=[3], cam_r0=[3], cam_r1=[3], cam_r2=[3], cam_b0=[3], lidar_pc=[3])
)
# Out:
# /tmp/ipykernel_3831590/1247388147.py:18: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(config_path="../navsim/planning/script/config/common/train_test_split/scene_filter")
# /tmp/ipykernel_3831590/1247388147.py:24: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(config_path="../navsim/planning/script/config/pdm_scoring")
# Loading logs: 100%|██████████| 136/136 [00:07<00:00, 19.15it/s]

# %%
some_token = scene_loader.tokens[0]
frame0 = scene_loader.scene_frames_dicts[some_token][0]
print("lidar_path:", frame0["lidar_path"])
print(frame0["cams"].keys())
print({k: v["data_path"] for k, v in frame0["cams"].items()})
# Out:
# lidar_path: 2021.09.29.19.02.14_veh-28_03198_03360/MergedPointCloud/05b23d026d975eda.pcd
# dict_keys(['CAM_F0', 'CAM_L0', 'CAM_R0', 'CAM_L1', 'CAM_R1', 'CAM_L2', 'CAM_R2', 'CAM_B0'])
# {'CAM_F0': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_F0/1401e630363c5896.jpg', 'CAM_L0': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_L0/c279d83be37d5546.jpg', 'CAM_R0': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_R0/b361670c692f5188.jpg', 'CAM_L1': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_L1/6b990111e213520e.jpg', 'CAM_R1': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_R1/14e6871c937255e2.jpg', 'CAM_L2': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_L2/e5c7618ab1a6597a.jpg', 'CAM_R2': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_R2/1487b278fe875c6c.jpg', 'CAM_B0': '2021.09.29.19.02.14_veh-28_03198_03360/CAM_B0/8c3907a480085339.jpg'}

# %% [markdown]
# ## Birds-Eye-View <a name="bev"></a>
#
# The Birds-Eye-View (BEV) visualization in NAVSIM is useful for overviewing the map, bounding-box annotations, or the LiDAR point cloud. In standard setting, the BEV plot includes a 64m $\times$ 64m frame centered at the rear axle of the ego vehicle (excluding LiDAR for simplicity). First, we take a random token and load a scene to visualize.

# %%
token = np.random.choice(scene_loader.tokens)
print(f"Visualizing scene with token: {token}")
scene = scene_loader.get_scene_from_token(token)
# Out:
# Visualizing scene with token: d0dc567530ef57dd
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 token = np.random.choice(scene_loader.tokens)
#       2 print(f"Visualizing scene with token: {token}")
# ----> 3 scene = scene_loader.get_scene_from_token(token)
#
# File /workspace/wangch8@xiaopeng.com/github/DiffusionDrive/navsim/common/dataloader.py:119, in SceneLoader.get_scene_from_token(self, token)
#     113 """
#     114 Loads scene given a scene identifier string (token).
#     115 :param token: scene identifier string.
#     116 :return: scene dataclass
#     117 """
#     118 assert token in self.tokens
# --> 119 return Scene.from_scene_dict_list(
#     120     self.scene_frames_dicts[token],
#     121     self._sensor_blobs_path,
#     122     num_history_frames=self._scene_filter.num_history_frames,
#     123     num_future_frames=self._scene_filter.num_future_frames,
#     124     sensor_config=self._sensor_config,
#     125 )
#
# File /workspace/wangch8@xiaopeng.com/github/DiffusionDrive/navsim/common/dataclasses.py:430, in Scene.from_scene_dict_list(cls, scene_dict_list, sensor_blobs_path, num_history_frames, num_future_frames, sensor_config)
#     421 assert len(scene_dict_list) >= 0, "Scene list is empty!"
#     422 scene_metadata = SceneMetadata(
#     423     log_name=scene_dict_list[num_history_frames - 1]["log_name"],
#     424     scene_token=scene_dict_list[num_history_frames - 1]["scene_token"],
#    (...)
#     428     num_future_frames=num_future_frames,
#     429 )
# --> 430 map_api = cls._build_map_api(scene_metadata.map_name)
#     432 frames: List[Frame] = []
#     433 for frame_idx in range(len(scene_dict_list)):
#
# File /workspace/wangch8@xiaopeng.com/github/DiffusionDrive/navsim/common/dataclasses.py:372, in Scene._build_map_api(cls, map_name)
#     370 """Helper classmethod to load map api from name."""
#     371 assert map_name in MAP_LOCATIONS, f"The map name {map_name} is invalid, must be in {MAP_LOCATIONS}"
# --> 372 return get_maps_api(NUPLAN_MAPS_ROOT, "nuplan-maps-v1.0", map_name)
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/common/maps/nuplan_map/map_factory.py:60, in get_maps_api(map_root, map_version, map_name)
#      51 @lru_cache(maxsize=32)
#      52 def get_maps_api(map_root: str, map_version: str, map_name: str) -> NuPlanMap:
#      53     """
#      54     Get a NuPlanMap object corresponding to a particular set of parameters.
#      55     :param map_root: The root folder for the map data.
#    (...)
#      58     :return: The loaded NuPlanMap object.
#      59     """
# ---> 60     maps_db = get_maps_db(map_root, map_version)
#      61     return NuPlanMap(maps_db, map_name.replace(".gpkg", ""))
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/common/maps/nuplan_map/map_factory.py:48, in get_maps_db(map_root, map_version)
#      40 @lru_cache(maxsize=2)
#      41 def get_maps_db(map_root: str, map_version: str) -> GPKGMapsDB:
#      42     """
#      43     Get a maps_db from disk.
#      44     :param map_root: The root folder for the map data.
#      45     :param map_version: The version of the map to load.
#      46     :return; The loaded MapsDB object.
#      47     """
# ---> 48     return GPKGMapsDB(map_root=map_root, map_version=map_version)
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/database/maps_db/gpkg_mapsdb.py:72, in GPKGMapsDB.__init__(self, map_version, map_root)
#      69 self._map_version = map_version
#      70 self._map_root = map_root
# ---> 72 self._blob_store = BlobStoreCreator.create_mapsdb(map_root=self._map_root)
#      73 version_file = self._blob_store.get(f"{self._map_version}.json")  # get blob and save to disk
#      74 self._metadata = json.load(version_file)
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/database/common/blob_store/creator.py:54, in BlobStoreCreator.create_mapsdb(cls, map_root, verbose)
#      42 """
#      43 Create Maps DB blob storage.
#      44
#    (...)
#      47 :return: Blob storage created.
#      48 """
#      49 conf = RemoteConfig(
#      50     http_root_url=os.getenv("NUPLAN_MAPS_ROOT_HTTP_URL", ""),
#      51     s3_root_url=os.getenv("NUPLAN_MAPS_ROOT_S3_URL", ""),
#      52 )
# ---> 54 return cls.create(map_root, conf, verbose)
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/database/common/blob_store/creator.py:76, in BlobStoreCreator.create(cls, data_root, conf, verbose)
#      74 elif NUPLAN_DATA_STORE == "local":
#      75     logger.debug(f"Using local disk store at {data_root} with no remote store")
# ---> 76     return LocalStore(data_root)
#      77 # Default to S3 if environment variable is empty or not set.
#      78 elif NUPLAN_DATA_STORE == "s3":
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/site-packages/nuplan/database/common/blob_store/local_store.py:22, in LocalStore.__init__(self, root_dir)
#      17 """
#      18 Initialize LocalStore.
#      19 :param root_dir: Root directory containing the data.
#      20 """
#      21 self._root_dir = root_dir
# ---> 22 assert os.path.isdir(self._root_dir), '%s does not exist!' % self._root_dir
#      23 assert os.access(self._root_dir, os.R_OK | os.X_OK), 'can not read from %s' % self._root_dir
#
# File /workspace/wangch8@xiaopeng.com/software/miniconda3/envs/goalflow/lib/python3.10/genericpath.py:42, in isdir(s)
#      40 """Return true if the pathname refers to an existing directory."""
#      41 try:
# ---> 42     st = os.stat(s)
#      43 except (OSError, ValueError):
#      44     return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %% [markdown]
# The function `plot_bev_frame` takes a `Scene` and index of the step to visualize (history or future).

# %%
from navsim.visualization.plots import plot_bev_frame

frame_idx = scene.scene_metadata.num_history_frames - 1 # current frame
fig, ax = plot_bev_frame(scene, frame_idx)
plt.show()

# %% [markdown]
# The function `plot_bev_with_agent` visualizes the trajectory of an <span style="color:#DE7061">agent</span> in comparison to the <span style="color:#59a14f">human vehicle operator</span> at the current frame. This notebook shows an example of the naive `ConstantVelocityAgent`:

# %%
from navsim.visualization.plots import plot_bev_with_agent
from navsim.agents.constant_velocity_agent import ConstantVelocityAgent

agent = ConstantVelocityAgent()
fig, ax = plot_bev_with_agent(scene, agent)
plt.show()

# %% [markdown]
# ## Cameras <a name="bev"></a>
#
# The agents in NAVSIM have access to eight cameras surrounding the vehicle. The function `plot_cameras_frame` shows the cameras in a 3 $\times$ 3 grid with cameras in each direction of the ego-vehicle and the BEV plot in the center.

# %%
from navsim.visualization.plots import plot_cameras_frame

fig, ax = plot_cameras_frame(scene, frame_idx)
plt.show()

# %% [markdown]
# With `plot_cameras_frame_with_annotations`, you can visualize the bounding-box annotations in the camera images.

# %%
from navsim.visualization.plots import plot_cameras_frame_with_annotations

fig, ax = plot_cameras_frame_with_annotations(scene, frame_idx)
plt.show()

# %% [markdown]
# With `plot_cameras_frame_with_lidar`, you can visualize the LiDAR point cloud in the camera images.

# %%
from navsim.visualization.plots import plot_cameras_frame_with_lidar

fig, ax = plot_cameras_frame_with_lidar(scene, frame_idx)
plt.show()

# %% [markdown]
# ## Creating custom plots <a name="custom"></a>
#
# The plots in NAVSIM use `matplotlib` and either add elements to a `plt.Axes` object or return the full `plt.Figure`. Functions in [`navsim/visualization/`](https://github.com/autonomousvision/navsim/blob/main/navsim/navsim/visualization) can be re-used to create custom plots. In this example, we create a plot for the bounding-box annotations and the LiDAR point cloud.

# %%
from navsim.visualization.plots import configure_bev_ax
from navsim.visualization.bev import add_annotations_to_bev_ax, add_lidar_to_bev_ax


fig, ax = plt.subplots(1, 1, figsize=(6, 6))

ax.set_title("Custom plot")

add_annotations_to_bev_ax(ax, scene.frames[frame_idx].annotations)
add_lidar_to_bev_ax(ax, scene.frames[frame_idx].lidar)

# configures frame to BEV view
configure_bev_ax(ax)

plt.show()

# %% [markdown]
# ## Creating GIFs <a name="gifs"></a>
#
# You can transform frame-wise plots into short animated GIFs. Give any function to `frame_plot_to_gif`, which takes a `Scene` and `frame_idx` as input (ie. `plot_cameras_frame_with_annotations`).

# %%
from navsim.visualization.plots import frame_plot_to_gif

frame_indices = [idx for idx in range(len(scene.frames))]  # all frames in scene
file_name = f"./{token}.gif"
images = frame_plot_to_gif(file_name, plot_cameras_frame_with_annotations, scene, frame_indices)
